# %%
import pandas as pd
from openpyxl import load_workbook, Workbook, worksheet
import re
import json

# %%
wb = load_workbook("Sales_Data_With_Issues.xlsx")
wb

# %%
wb.sheetnames
# Out:
# ['Sales_Data', 'Summary', 'Hidden_Config']

# %%
raport_bledow = []

def audyt_excela(filepath):
    wb = load_workbook(filepath)
    raport_bledow = []

    for sheet in wb.sheetnames:
        obecny_arkusz = wb[sheet]
        if obecny_arkusz.sheet_state != "visible":
            raport_bledow.append(dict([("typ_bledu", "ukryty_arkusz")]))
        
        for row in obecny_arkusz.rows:
            for cell in row:
                komorka = cell.value
                lokalizacja = cell.coordinate
                if komorka is not None and str(komorka).startswith("="):
                    znalezione_hardkodowanie = re.findall(r'\b\d+(\.\d+)?', komorka)
                    if znalezione_hardkodowanie:
                        raport_bledow.append(dict([("typ_bledu", "hardkodowanie"), ("komorka", lokalizacja)]))
                
                if isinstance(komorka, str) and komorka != komorka.strip():
                    raport_bledow.append(
                        {"typ_bledu": "zbedne spacje", "komorka": lokalizacja}
                    )
        return json.dumps(raport_bledow, indent=4, ensure_ascii=False)

# %%
audyt_excela("Sales_Data_With_Issues.xlsx")
# Out:
# '[\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G2"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C3"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G3"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G4"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C5"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G5"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C6"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G6"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G7"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C8"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G8"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C9"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G9"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G10"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G11"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G12"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C13"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G13"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G14"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C15"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G15"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C16"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G16"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G17"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C18"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G18"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C19"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G19"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C20"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G20"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C21"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C22"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G22"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G23"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C24"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G24"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C25"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G25"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C26"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G26"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C27"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G27"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C28"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G28"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C29"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G29"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C30"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G30"\n    },\n    {\n        "typ_bledu": "hardkodowanie",\n        "komorka": "G32"\n    },\n    {\n        "typ_bledu": "zbedne spacje",\n        "komorka": "C33"\n    },\n    {\n   ...

# %%
.json
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 wb["Sales_Data"].rows.cell
#
# AttributeError: 'generator' object has no attribute 'cell'
